# %%
import pandas as pd

# %%
s1 = pd.read_csv('2018-19.csv')
s2=pd.read_csv('2019-20.csv')
s3=pd.read_csv('2020-2021.csv')
test = pd.read_csv('2021-2022.csv')

# %%
test.columns
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG',
#        ...
#        'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH',
#        'MaxCAHA', 'AvgCAHH', 'AvgCAHA'],
#       dtype='object', length=106)

# %%
def preprocessing(df):
  df.drop(['Div','Date','FTHG','FTAG','HTHG','HTAG','HTR','Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
       'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
       'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA',
       'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD',
       'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5',
       'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA',
       'PSCH', 'PSCD', 'PSCA'],axis =1,inplace = True)
  from sklearn.preprocessing import LabelEncoder
  lb = LabelEncoder()
  df['HomeTeam'] = lb.fit_transform(df['HomeTeam'])
  df['AwayTeam']=lb.fit_transform(df['AwayTeam'])

# %%
s2=  s2.reindex(columns=s1.columns,fill_value=0)
s3 = s3.reindex(columns=s1.columns,fill_value=0)
test = test.reindex(columns=s1.columns,fill_value=0)

# %%
preprocessing(s1)
preprocessing(s2)
preprocessing(s3)
preprocessing(test)

# %%
training= pd.concat([s1,s2,s3])

# %%
training.columns
# Out:
# Index(['HomeTeam', 'AwayTeam', 'FTR'], dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
X_train = training.drop(['FTR'],axis=1)
y_train = training['FTR']

X_test = test.drop(['FTR'],axis =1)
y_test = test['FTR']

# %%
model.fit(X_train,y_train)
predict = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,predict)
accuracy
# Out:
# 0.4105263157894737
